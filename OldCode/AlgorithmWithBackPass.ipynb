# %%
import msprime, tskit
from IPython.display import SVG
import numpy as np

# %%
ts = msprime.sim_ancestry(3, population_size=1000, sequence_length=1e5, recombination_rate=1e-8, random_seed=20)

# %%
ts.num_trees
# Out:
# 9

# %%
SVG(ts.draw_svg())

# %%
def extend_edges(ts):
    edgediffs = ts.edge_diffs()
    trees1 = ts.trees()
    trees2 = ts.trees()
    _ = next(trees1)
    _ = next(edgediffs)


    t = ts.tables
    edges = t.edges
    new_left = edges.left
    new_right = edges.right

    max_n = 100
    pending_out = []
    pending_in = []
    # note we skip the first tree
    for last_tree, next_tree, (interval, edges_out, edges_in) in zip(trees2, trees1, edgediffs):
        assert interval == next_tree.interval
        if False:
            print("edges_in", interval)
            for e in edges_in:
                print("-->", e)
            print("pending in", interval)
            for e in pending_in:
                print("--->", e)
            print("edges_out", interval)
            for e in edges_out:
                print("-->", e)
            print("pending out", interval)
            for e in pending_out:
                print("--->", e)
        edges_out.extend(pending_out)
        edges_in.extend(pending_in)
        pending_out = []
        pending_in = []
        extended = [False for _ in edges_out]
        for j1, e1 in enumerate(edges_out):
            # assert last_tree.parent(e1.child) == e1.parent
            if not extended[j1]:
                for j2, e2 in enumerate(edges_out):
                    if not extended[j2]:
                        if e1.parent == e2.child:
                            for e_in in edges_in:
                                if e_in.right > interval.left:
                                    # assert next_tree.parent(e_in.child) == e_in.parent
                                    if e1.child == e_in.child and e2.parent == e_in.parent:
                                        # print("     ", interval, e1.child, "-", e1.parent, "-", e2.parent, " -> ", e_in)
                                        max_n -= 1
                                        if max_n <= 0:
                                            assert False
                                        print("ping!!", e1.id, "+", e2.id, "=", e_in.id)
                                        # extend e1 and e2, postpone e_in
                                        extended[j1] = True
                                        extended[j2] = True
                                        pending_out.extend([e1, e2])
                                        pending_in.append(e_in)
                                        new_right[e1.id] = interval.right
                                        new_right[e2.id] = interval.right
                                        new_left[e_in.id] = interval.right
                                        # TODO fix up this terrible flow control 
                                        # to make sure that the same edges aren't extended more than once
    keep = new_left < new_right
    edges.set_columns(
        left=new_left[keep],
        right=new_right[keep],
        parent=edges.parent[keep],
        child=edges.child[keep])
    new_ts = t.tree_sequence()
    return new_ts

# %%
new_ts = extend_edges(ts)
SVG(new_ts.draw_svg())
# Out:
# ping!! 1 + 9 = 8
# ping!! 1 + 9 = 8
# ping!! 8 + 13 = 11
# ping!! 8 + 13 = 11
# ping!! 8 + 13 = 11
# ping!! 25 + 33 = 30
# ping!! 8 + 13 = 11
# ping!! 27 + 34 = 29

# %%
def verify_extending(ts):
    ets = extend_edges(ts)
    sts = ets.simplify()
    sts.tables.assert_equals(ts.tables, ignore_provenance=True)
    print("old edges:", ts.num_edges, "new edges:", ets.num_edges)
    eets = extend_edges(ets)
    
verify_extending(ts)
# Out:
# ping!! 1 + 9 = 8
# ping!! 1 + 9 = 8
# ping!! 8 + 13 = 11
# ping!! 8 + 13 = 11
# ping!! 8 + 13 = 11
# ping!! 25 + 33 = 30
# ping!! 8 + 13 = 11
# ping!! 27 + 34 = 29
# old edges: 35 new edges: 32
# ping!! 1 + 9 = 8
# ping!! 1 + 9 = 8
# ping!! 1 + 9 = 8
# ping!! 1 + 9 = 8

# %%
ets = extend_edges(ts)
print("----")
eets = extend_edges(ets)
print("----")
eeets = extend_edges(eets)
# Out:
# ping!! 1 + 9 = 8
# ping!! 1 + 9 = 8
# ping!! 8 + 13 = 11
# ping!! 8 + 13 = 11
# ping!! 8 + 13 = 11
# ping!! 25 + 33 = 30
# ping!! 8 + 13 = 11
# ping!! 27 + 34 = 29
# ----
# ping!! 1 + 9 = 8
# ping!! 1 + 9 = 8
# ping!! 1 + 9 = 8
# ping!! 1 + 9 = 8
# ----

# %%
for seed in range(1, 100):
    print("----", seed)
    ts = msprime.sim_ancestry(3, population_size=1000, sequence_length=1e5, recombination_rate=1e-8, random_seed=seed)
    verify_extending(ts)
# Out:
# ---- 1
# ping!! 10 + 13 = 11
# old edges: 22 new edges: 21
# ---- 2
# ping!! 3 + 6 = 5
# ping!! 8 + 17 = 16
# ping!! 3 + 6 = 5
# ping!! 10 + 23 = 21
# ping!! 8 + 17 = 16
# ping!! 3 + 6 = 5
# ping!! 3 + 6 = 5
# old edges: 25 new edges: 22
# ---- 3
# old edges: 22 new edges: 22
# ---- 4
# ping!! 9 + 15 = 14
# ping!! 9 + 15 = 14
# ping!! 12 + 30 = 28
# ping!! 6 + 21 = 18
# ping!! 12 + 30 = 28
# ping!! 6 + 21 = 18
# ping!! 6 + 21 = 18
# ping!! 20 + 38 = 37
# old edges: 46 new edges: 42
# ---- 5
# ping!! 5 + 15 = 14
# ping!! 5 + 15 = 14
# ping!! 3 + 14 = 13
# ping!! 3 + 14 = 13
# ping!! 21 + 28 = 26
# ping!! 21 + 28 = 26
# old edges: 33 new edges: 31
# ping!! 5 + 14 = 13
# ping!! 5 + 14 = 13
# ---- 6
# ping!! 3 + 6 = 4
# ping!! 3 + 6 = 4
# ping!! 3 + 6 = 4
# ping!! 3 + 6 = 4
# ping!! 3 + 6 = 4
# ping!! 1 + 19 = 18
# ping!! 3 + 6 = 4
# ping!! 21 + 30 = 28
# ping!! 3 + 6 = 4
# ping!! 3 + 6 = 4
# ping!! 3 + 6 = 4
# ping!! 3 + 6 = 4
# ping!! 3 + 6 = 4
# old edges: 40 new edges: 37
# ---- 7
# ping!! 12 + 25 = 21
# ping!! 12 + 25 = 21
# ping!! 12 + 25 = 21
# old edges: 32 new edges: 31
# ---- 8
# ping!! 7 + 11 = 10
# ping!! 9 + 19 = 18
# ping!! 12 + 20 = 16
# ping!! 9 + 19 = 18
# ping!! 12 + 20 = 16
# ping!! 9 + 19 = 18
# old edges: 28 new edges: 25
# ---- 9
# ping!! 7 + 20 = 19
# old edges: 22 new edges: 21
# ---- 10
# ping!! 6 + 12 = 10
# ping!! 6 + 12 = 10
# ping!! 6 + 12 = 10
# ping!! 6 + 12 = 10
# ping!! 10 + 27 = 25
# ping!! 5 + 15 = 13
# old edges: 33 new edges: 31
# ping!! 6 + 12 = 10
# ---- 11
# ping!! 8 + 15 = 12
# old edges: 17 new edges: 16
# ---- 12
# ping!! 10 + 25 = 18
# ping!! 4 + 16 = 14
# ping!! 10 + 25 = 18
# ping!! 7 + 23 = 21
# ping!! 4 + 16 = 14
# ping!! 4 + 16 = 14
# ping!! 4 + 16 = 14
# ping!! 4 + 16 = 14
# ping!! 4 + 16 = 14
# ping!! 15 + 34 = 32
# old edges: 44 new edges: 40
# ---- 13
# ping!! 11 + 41 = 37
# ping!! 11 + 41 = 37
# ping!! 11 + 41 = 37
# ping!! 18 + 34 = 29
# ping!! 11 + 41 = 37
# ping!! 32 + 44 = 42
# ping!! 13 + 42 = 38
# ping!! 5 + 16 = 15
# ping!! 3 + 30 = 28
# ping!! 5 + 16 = 15
# ping!! 5 + 16 = 15
# old edges: 47 new edges: 42
# ping!! 29 + 39 = 37
# ping!! 13 + 29 = 27
# ping!! 13 + 29 = 27
# ping!! 13 + 29 = 27
# ping!! 13 + 29 = 27
# ---- 14
# ping!! 26 + 45 = 41
# ping!! 15 + 43 = 39
# ping!! 5 + 11 = 7
# ping!! 15 + 43 = 39
# ping!! 5 + 11 = 7
# ping!! 0 + 10 = 9
# ping!! 5 + 11 = 7
# ping!! 0 + 10 = 9
# ping!! 5 + 11 = 7
# ping!! 0 + 10 = 9
# ping!! 5 + 11 = 7
# ping!! 29 + 38 = 32
# old edges: 62 new edges: 57
# ---- 15
# ping!! 7 + 15 = 13
# ping!! 7 + 15 = 13
# ping!! 7 + 15 = 13
# ping!! 7 + 15 = 13
# ping!! 8 + 23 = 22
# old edges: 39 new edges: 37
# ---- 16
# ping!! 4 + 9 = 6
# ping!! 13 + 34 = 32
# ping!! 4 + 9 = 6
# ping!! 4 + 9 = 6
# ping!! 4 + 9 = 6
# ping!! 2 + 8 = 7
# ping!! 4 + 9 = 6
# ping!! 2 + 8 = 7
# ping!! 4 + 9 = 6
# ping!! 2 + 8 = 7
# ping!! 4 + 9 = 6
# ping!! 2 + 8 = 7
# ping!! 4 + 9 = 6
# ping!! 2 + 8 = 7
# ping!! 4 + 9 = 6
# old edges: 36 new edges: 33
# ---- 17
# ping!! 7 + 11 = 9
# old edges: 21 new edges: 20
# ---- 18
# old edges: 16 new edges: 16
# ---- 19
# ping!! 10 + 23 = 20
# ping!! 2 + 6 = 4
# ping!! 2 + 6 = 4
# ping!! 2 + 6 = 4
# ping!! 16 + 25 = 22
# ping!! 2 + 6 = 4
# ping!! 2 + 6 = 4
# ping!! 2 + 6 = 4
# ping!! 2 + 6 = 4
# ping!! 2 + 6 = 4
# ping!! 2 + 6 = 4
# old edges: 37 new edges: 34
# ---- 20
# ping!! 1 + 9 = 8
# ping!! 1 + 9 = 8
# ping!! 8 + 13 = 11
# ping!! 8 + 13 = 11
# ping!! 8 + 13 = 11
# ping!! 25 + 33 = 30
# ping!! 8 + 13 = 11
# ping!! 27 + 34 = 29
# old edges: 35 new edges: 32
# ping!! 1 + 9 = 8
# ping!! 1 + 9 = 8
# ping!! 1 + 9 = 8
# ping!! 1 + 9 = 8
# ---- 21
# ping!! 6 + 9 = 8
# ping!! 8 + 12 = 11
# ping!! 16 + 22 = 19
# ping!! 8 + 12 = 11
# ping!! 8 + 12 = 11
# ping!! 8 + 12 = 11
# old edges: 28 new edges: 26
# ping!! 6 + 9 = 8
# ping!! 6 + 9 = 8
# ping!! 6 + 9 = 8
# ping!! 6 + 9 = 8
# ---- 22
# ping!! 6 + 17 = 16
# ping!! 4 + 12 = 11
# ping!! 6 + 17 = 16
# ping!! 4 + 12 = 11
# ping!! 4 + 12 = 11
# old edges: 28 new edges: 26
# ---- 23
# ping!! 3 + 8 = 7
# ping!! 16 + 30 = 29
# ping!! 3 + 8 = 7
# ping!! 3 + 8 = 7
# ping!! 17 + 21 = 19
# ping!! 3 + 8 = 7
# ping!! 20 + 27 = 24
# ping!! 3 + 8 = 7
# ping!! 3 + 8 = 7
# ping!! 3 + 8 = 7
# ping!! 14 + 34 = 32
# ping!! 3 + 8 = 7
# old edges: 37 new edges: 32
# ---- 24
# ping!! 9 + 21 = 20
# ping!! 4 + 20 = 19
# old edges: 23 new edges: 22
# ping!! 9 + 20 = 19
# ---- 25
# ping!! 6 + 12 = 11
# ping!! 10 + 18 = 16
# old edges: 21 new edges: 19
# ---- 26
# ping!! 14 + 24 = 21
# ping!! 14 + 24 = 21
# ping!! 9 + 32 = 30
# ping!! 28 + 37 = 35
# old edges: 38 new edges: 35
# ---- 27
# ping!! 6 + 12 = 10
# old edges: 14 new edges: 13
# ---- 28
# ping!! 14 + 23 = 21
# ping!! 14 + 23 = 21
# ping!! 10 + 28 = 26
# ping!! 10 + 28 = 26
# old edges: 38 new edges: 36
# ---- 29
# ping!! 7 + 41 = 40
# ping!! 14 + 37 = 35
# ping!! 9 + 29 = 27
# ping!! 18 + 31 = 26
# ping!! 4 + 23 = 21
# ping!! 4 + 23 = 21
# ping!! 4 + 23 = 21
# ping!! 4 + 23 = 21
# old edges: 44 new edges: 39
# ---- 30
# ping!! 2 + 17 = 15
# ping!! 10 + 22 = 21
# ping!! 10 + 22 = 21
# ping!! 10 + 22 = 21
# old edges: 36 new edges: 34
# ---- 31
# ping!! 4 + 8 = 6
# ping!! 4 + 8 = 6
# ping!! 9 + 23 = 21
# ping!! 16 + 20 = 18
# old edges: 36 new edges: 33
# ---- 32
# ping!! 6 + 14 = 12
# old edges: 22 new edges: 21
# ---- 33
# ping!! 14 + 21 = 19
# ping!! 14 + 21 = 19
# ping!! 14 + 21 = 19
# ping!! 14 + 21 = 19
# ping!! 3 + 26 = 24
# ping!! 17 + 29 = 28
# ping!! 3 + 26 = 24
# old edges: 32 new edges: 29
# ---- 34
# old edges: 16 new edges: 16
# ---- 35
# ping!! 2 + 14 = 12
# ping!! 2 + 14 = 12
# ping!! 16 + 33 = 30
# ping!! 11 + 37 = 34
# ping!! 18 + 38 = 36
# old edges: 42 new edges: 38
# ---- 36
# ping!! 8 + 17 = 14
# ping!! 8 + 17 = 14
# old edges: 19 new edges: 18
# ---- 37
# ping!! 10 + 17 = 16
# old edges: 20 new edges: 19
# ---- 38
# ping!! 10 + 19 = 16
# ping!! 14 + 21 = 17
# old edges: 24 new edges: 22
# ---- 39
# ping!! 16 + 26 = 23
# old edges: 31 new edges: 30
# ---- 40
# ping!! 5 + 8 = 7
# ping!! 16 + 33 = 32
# ping!! 5 + 8 = 7
# ping!! 11 + 16 = 15
# ping!! 5 + 8 = 7
# ping!! 11 + 16 = 15
# ping!! 5 + 8 = 7
# ping!! 3 + 15 = 13
# ping!! 5 + 8 = 7
# ping!! 7 + 22 = 21
# ping!! 3 + 15 = 13
# ping!! 3 + 15 = 13
# ping!! 3 + 15 = 13
# ping!! 20 + 26 = 24
# ping!! 3 + 15 = 13
# old edges: 38 new edges: 34
# ping!! 11 + 15 = 14
# ping!! 5 + 8 = 7
# ping!! 11 + 15 = 14
# ping!! 11 + 15 = 14
# ping!! 11 + 15 = 14
# ping!! 11 + 15 = 14
# ---- 41
# ping!! 1 + 18 = 16
# ping!! 15 + 30 = 29
# ping!! 1 + 18 = 16
# ping!! 1 + 18 = 16
# ping!! 1 + 18 = 16
# ping!! 1 + 18 = 16
# ping!! 12 + 43 = 42
# ping!! 1 + 18 = 16
# ping!! 1 + 18 = 16
# ping!! 19 + 38 = 36
# old edges: 45 new edges: 41
# ---- 42
# ping!! 10 + 14 = 13
# ping!! 10 + 14 = 13
# ping!! 10 + 14 = 13
# ping!! 10 + 14 = 13
# ping!! 12 + 23 = 19
# old edges: 28 new edges: 26
# ---- 43
# ping!! 3 + 8 = 7
# ping!! 3 + 8 = 7
# old edges: 19 new edges: 18
# ---- 44
# ping!! 7 + 12 = 10
# old edges: 22 new edges: 21
# ---- 45
# ping!! 9 + 21 = 19
# old edges: 23 new edges: 22
# ---- 46
# ping!! 7 + 15 = 14
# ping!! 5 + 21 = 20
# ping!! 5 + 21 = 20
# old edges: 25 new edges: 23
# ---- 47
# ping!! 8 + 11 = 10
# old edges: 26 new edges: 25
# ---- 48
# ping!! 23 + 35 = 27
# ping!! 26 + 36 = 30
# ping!! 10 + 38 = 37
# ping!! 10 + 38 = 37
# old edges: 47 new edges: 44
# ---- 49
# old edges: 20 new edges: 20
# ---- 50
# ping!! 6 + 13 = 11
# ping!! 22 + 31 = 28
# ping!! 6 + 13 = 11
# ping!! 9 + 26 = 25
# ping!! 6 + 13 = 11
# ping!! 4 + 25 = 23
# ping!! 12 + 18 = 17
# old edges: 34 new edges: 30
# ping!! 9 + 23 = 22
# ---- 51
# ping!! 6 + 14 = 13
# ping!! 15 + 20 = 19
# old edges: 23 new edges: 21
# ---- 52
# ping!! 14 + 19 = 18
# old edges: 34 new edges: 33
# ---- 53
# ping!! 13 + 48 = 44
# ping!! 15 + 49 = 47
# ping!! 15 + 49 = 47
# ping!! 39 + 54 = 41
# ping!! 11 + 37 = 35
# ping!! 39 + 54 = 41
# ping!! 25 + 38 = 34
# ping!! 11 + 37 = 35
# ping!! 25 + 38 = 34
# ping!! 11 + 37 = 35
# ping!! 34 + 60 = 55
# ping!! 21 + 33 = 31
# ping!! 26 + 51 = 43
# ping!! 21 + 33 = 31
# ping!! 21 + 33 = 31
# ping!! 21 + 33 = 31
# ping!! 32 + 67 = 64
# ping!! 29 + 66 = 62
# ping!! 32 + 67 = 64
# ping!! 29 + 66 = 62
# ping!! 32 + 67 = 64
# ping!! 19 + 64 = 63
# old edges: 68 new edges: 59
# ping!! 25 + 36 = 33
# ping!! 31 + 58 = 55
# ---- 54
# ping!! 7 + 11 = 9
# ping!! 7 + 11 = 9
# ping!! 7 + 11 = 9
# ping!! 13 + 18 = 17
# ping!! 7 + 11 = 9
# ping!! 13 + 18 = 17
# ping!! 7 + 11 = 9
# ping!! 13 + 18 = 17
# ping!! 7 + 11 = 9
# ping!! 9 + 17 = 15
# ping!! 22 + 31 = 30
# ping!! 9 + 17 = 15
# ping!! 24 + 32 = 28
# ping!! 22 + 31 = 30
# old edges: 37 new edges: 34
# ping!! 13 + 17 = 16
# ping!! 7 + 11 = 9
# ping!! 13 + 17 = 16
# ping!! 7 + 11 = 9
# ---- 55
# ping!! 5 + 10 = 9
# ping!! 5 + 10 = 9
# ping!! 8 + 22 = 20
# ping!! 11 + 23 = 19
# ping!! 8 + 22 = 20
# ping!! 19 + 33 = 31
# ping!! 19 + 33 = 31
# ping!! 7 + 16 = 14
# old edges: 36 new edges: 32
# ping!! 10 + 20 = 17
# ping!! 10 + 20 = 17
# ---- 56
# ping!! 8 + 19 = 18
# ping!! 6 + 13 = 11
# ping!! 10 + 16 = 14
# old edges: 25 new edges: 22
# ---- 57
# ping!! 2 + 6 = 5
# ping!! 7 + 16 = 15
# ping!! 2 + 6 = 5
# old edges: 20 new edges: 18
# ---- 58
# ping!! 8 + 14 = 13
# ping!! 8 + 14 = 13
# ping!! 17 + 27 = 25
# ping!! 2 + 6 = 4
# ping!! 17 + 27 = 25
# ping!! 2 + 6 = 4
# old edges: 31 new edges: 28
# ---- 59
# ping!! 13 + 18 = 14
# ping!! 13 + 18 = 14
# ping!! 16 + 26 = 23
# ping!! 2 + 6 = 4
# ping!! 16 + 26 = 23
# ping!! 11 + 25 = 22
# ping!! 2 + 6 = 4
# ping!! 11 + 25 = 22
# ping!! 2 + 6 = 4
# ping!! 4 + 9 = 7
# ping!! 11 + 25 = 22
# ping!! 27 + 34 = 33
# ping!! 4 + 9 = 7
# old edges: 36 new edges: 31
# ping!! 2 + 6 = 4
# ping!! 2 + 6 = 4
# ---- 60
# ping!! 10 + 13 = 12
# old edges: 18 new edges: 17
# ---- 61
# old edges: 14 new edges: 14
# ---- 62
# ping!! 12 + 19 = 16
# ping!! 5 + 10 = 9
# ping!! 5 + 10 = 9
# old edges: 26 new edges: 24
# ---- 63
# old edges: 15 new edges: 15
# ---- 64
# ping!! 4 + 10 = 8
# ping!! 4 + 10 = 8
# ping!! 6 + 17 = 15
# ping!! 4 + 10 = 8
# ping!! 18 + 22 = 20
# ping!! 4 + 10 = 8
# old edges: 27 new edges: 24
# ---- 65
# ping!! 8 + 30 = 27
# ping!! 1 + 4 = 3
# ping!! 11 + 24 = 20
# ping!! 1 + 4 = 3
# ping!! 16 + 26 = 23
# ping!! 1 + 4 = 3
# ping!! 13 + 25 = 21
# ping!! 16 + 26 = 23
# ping!! 1 + 4 = 3
# ping!! 18 + 32 = 29
# ping!! 13 + 25 = 21
# ping!! 16 + 26 = 23
# ping!! 1 + 4 = 3
# ping!! 13 + 25 = 21
# ping!! 16 + 26 = 23
# ping!! 1 + 4 = 3
# ping!! 33 + 38 = 37
# ping!! 13 + 25 = 21
# ping!! 16 + 26 = 23
# ping!! 1 + 4 = 3
# old edges: 40 new edges: 33
# ---- 66
# ping!! 7 + 12 = 11
# ping!! 11 + 20 = 18
# ping!! 11 + 20 = 18
# ping!! 1 + 29 = 28
# ping!! 11 + 20 = 18
# ping!! 18 + 32 = 30
# ping!! 8 + 26 = 24
# old edges: 40 new edges: 37
# ping!! 7 + 12 = 11
# ping!! 7 + 12 = 11
# ping!! 7 + 12 = 11
# ping!! 11 + 20 = 18
# ---- 67
# ping!! 5 + 26 = 25
# ping!! 13 + 19 = 16
# ping!! 17 + 23 = 21
# ping!! 7 + 11 = 9
# old edges: 28 new edges: 24
# ---- 68
# ping!! 14 + 23 = 22
# ping!! 14 + 23 = 22
# ping!! 8 + 30 = 29
# ping!! 8 + 30 = 29
# ping!! 11 + 28 = 27
# ping!! 11 + 28 = 27
# ping!! 11 + 28 = 27
# ping!! 26 + 39 = 33
# ping!! 12 + 37 = 35
# ping!! 12 + 37 = 35
# old edges: 50 new edges: 45
# ---- 69
# ping!! 8 + 14 = 12
# ping!! 0 + 4 = 2
# old edges: 21 new edges: 19
# ---- 70
# ping!! 4 + 14 = 13
# ping!! 12 + 17 = 16
# old edges: 20 new edges: 18
# ---- 71
# ping!! 18 + 22 = 19
# ping!! 18 + 22 = 19
# ping!! 10 + 36 = 32
# ping!! 2 + 47 = 44
# ping!! 2 + 47 = 44
# ping!! 24 + 31 = 30
# ping!! 24 + 31 = 30
# old edges: 58 new edges: 54
# ---- 72
# ping!! 5 + 15 = 12
# ping!! 5 + 15 = 12
# ping!! 22 + 34 = 31
# ping!! 22 + 34 = 31
# ping!! 18 + 27 = 24
# ping!! 18 + 27 = 24
# old edges: 41 new edges: 38
# ---- 73
# old edges: 21 new edges: 21
# ---- 74
# ping!! 2 + 11 = 8
# ping!! 2 + 11 = 8
# ping!! 2 + 11 = 8
# ping!! 2 + 11 = 8
# old edges: 32 new edges: 31
# ---- 75
# ping!! 13 + 17 = 15
# ping!! 13 + 17 = 15
# ping!! 13 + 17 = 15
# ping!! 11 + 16 = 14
# ping!! 13 + 17 = 15
# old edges: 22 new edges: 20
# ---- 76
# ping!! 4 + 8 = 6
# old edges: 18 new edges: 17
# ---- 77
# ping!! 5 + 16 = 14
# old edges: 20 new edges: 19
# ---- 78
# ping!! 7 + 11 = 10
# ping!! 7 + 11 = 10
# ping!! 7 + 11 = 10
# ping!! 5 + 10 = 9
# ping!! 5 + 10 = 9
# ping!! 5 + 10 = 9
# ping!! 5 + 10 = 9
# ping!! 8 + 20 = 19
# ping!! 8 + 20 = 19
# old edges: 40 new edges: 38
# ping!! 7 + 10 = 9
# ping!! 7 + 10 = 9
# ping!! 7 + 10 = 9
# ping!! 7 + 10 = 9
# ---- 79
# ping!! 10 + 13 = 12
# ping!! 6 + 10 = 9
# old edges: 19 new edges: 17
# ---- 80
# ping!! 0 + 9 = 6
# ping!! 3 + 10 = 8
# ping!! 0 + 9 = 6
# ping!! 3 + 10 = 8
# ping!! 0 + 9 = 6
# ping!! 8 + 13 = 12
# ping!! 8 + 13 = 12
# ping!! 8 + 13 = 12
# old edges: 30 new edges: 28
# ping!! 3 + 9 = 7
# ping!! 3 + 9 = 7
# ping!! 3 + 9 = 7
# ---- 81
# ping!! 6 + 12 = 8
# old edges: 19 new edges: 18
# ---- 82
# ping!! 4 + 8 = 6
# ping!! 4 + 8 = 6
# old edges: 28 new edges: 27
# ---- 83
# ping!! 13 + 23 = 22
# ping!! 11 + 22 = 21
# ping!! 4 + 21 = 19
# old edges: 27 new edges: 26
# ping!! 13 + 22 = 21
# ping!! 11 + 21 = 20
# ---- 84
# ping!! 4 + 15 = 14
# old edges: 26 new edges: 25
# ---- 85
# ping!! 6 + 26 = 25
# ping!! 8 + 16 = 13
# ping!! 8 + 16 = 13
# ping!! 19 + 22 = 21
# ping!! 8 + 16 = 13
# ping!! 19 + 22 = 21
# ping!! 8 + 16 = 13
# old edges: 33 new edges: 30
# ---- 86
# ping!! 8 + 17 = 15
# ping!! 7 + 26 = 25
# old edges: 28 new edges: 26
# ---- 87
# ping!! 24 + 31 = 29
# ping!! 8 + 29 = 27
# ping!! 12 + 35 = 32
# ping!! 12 + 35 = 32
# ping!! 15 + 22 = 20
# ping!! 12 + 35 = 32
# ping!! 15 + 22 = 20
# ping!! 15 + 22 = 20
# old edges: 40 new edges: 37
# ping!! 23 + 29 = 27
# ---- 88
# ping!! 18 + 24 = 22
# ping!! 10 + 19 = 16
# old edges: 32 new edges: 30
# ---- 89
# ping!! 10 + 22 = 18
# ping!! 12 + 31 = 24
# ping!! 8 + 29 = 26
# old edges: 34 new edges: 31
# ---- 90
# ping!! 8 + 19 = 17
# ping!! 21 + 39 = 37
# ping!! 21 + 39 = 37
# ping!! 24 + 34 = 31
# ping!! 6 + 18 = 16
# ping!! 23 + 33 = 32
# ping!! 6 + 18 = 16
# old edges: 41 new edges: 36
# ---- 91
# ping!! 8 + 11 = 10
# ping!! 16 + 32 = 31
# ping!! 8 + 11 = 10
# ping!! 9 + 20 = 18
# ping!! 16 + 32 = 31
# ping!! 19 + 29 = 25
# ping!! 16 + 32 = 31
# ping!! 19 + 29 = 25
# ping!! 19 + 29 = 25
# ping!! 19 + 29 = 25
# ping!! 19 + 29 = 25
# ping!! 2 + 6 = 5
# ping!! 19 + 29 = 25
# old edges: 45 new edges: 40
# ---- 92
# ping!! 5 + 11 = 10
# ping!! 5 + 11 = 10
# ping!! 12 + 20 = 18
# old edges: 23 new edges: 21
# ---- 93
# old edges: 14 new edges: 14
# ---- 94
# ping!! 6 + 25 = 23
# ping!! 23 + 32 = 29
# ping!! 10 + 16 = 12
# ping!! 10 + 16 = 12
# old edges: 33 new edges: 31
# ping!! 6 + 24 = 22
# ---- 95
# ping!! 7 + 10 = 8
# ping!! 14 + 18 = 17
# ping!! 7 + 10 = 8
# old edges: 21 new edges: 19
# ---- 96
# ping!! 4 + 23 = 22
# old edges: 28 new edges: 27
# ---- 97
# old edges: 12 new edges: 12
# ---- 98
# ping!! 10 + 16 = 14
# ping!! 10 + 16 = 14
# ping!! 8 + 21 = 17
# ping!! 13 + 22 = 19
# old edges: 28 new edges: 25
# ---- 99
# ping!! 8 + 14 = 10
# old edges: 23 new edges: 22

# %%
def extend_edges_back_pass(ts):
    edgediffs = ts.edge_diffs()
    trees1 = ts.trees()
    trees2 = ts.trees()
    _ = next(trees1)
    _ = next(edgediffs)


    t = ts.tables
    edges = t.edges
    new_left = edges.left
    new_right = edges.right

    max_n = 100
    pending_out = []
    pending_in = []
    
    ' Forward Pass through the Tree Sequence '
    # note we skip the first tree
    for last_tree, next_tree, (interval, edges_out, edges_in) in zip(trees2, trees1, edgediffs):
        assert interval == next_tree.interval
        if False:
            print("edges_in", interval)
            for e in edges_in:
                print("-->", e)
            print("pending in", interval)
            for e in pending_in:
                print("--->", e)
            print("edges_out", interval)
            for e in edges_out:
                print("-->", e)
            print("pending out", interval)
            for e in pending_out:
                print("--->", e)
        edges_out.extend(pending_out)
        edges_in.extend(pending_in)
        pending_out = []
        pending_in = []
        extended = [False for _ in edges_out]
        for j1, e1 in enumerate(edges_out):
            # assert last_tree.parent(e1.child) == e1.parent
            if not extended[j1]:
                for j2, e2 in enumerate(edges_out):
                    if not extended[j2]:
                        if e1.parent == e2.child:
                            for e_in in edges_in:
                                if e_in.right > interval.left:
                                    # assert next_tree.parent(e_in.child) == e_in.parent
                                    if e1.child == e_in.child and e2.parent == e_in.parent:
                                        # print("     ", interval, e1.child, "-", e1.parent, "-", e2.parent, " -> ", e_in)
                                        max_n -= 1
                                        if max_n <= 0:
                                            assert False
                                        print("ping!!", e1.id, "+", e2.id, "=", e_in.id)
                                        # extend e1 and e2, postpone e_in
                                        extended[j1] = True
                                        extended[j2] = True
                                        pending_out.extend([e1, e2])
                                        pending_in.append(e_in)
                                        new_right[e1.id] = interval.right
                                        new_right[e2.id] = interval.right
                                        new_left[e_in.id] = interval.right
                                        # TODO fix up this terrible flow control 
                                        # to make sure that the same edges aren't extended more than once
    
    ' Backward Pass through the Tree Sequence '
    for last_tree, next_tree, (interval, edges_out, edges_in) in zip(trees2, trees1, edgediffs):
        assert interval == next_tree.interval
        if False:
            print("edges_in", interval)
            for e in edges_in:
                print("-->", e)
            print("pending in", interval)
            for e in pending_in:
                print("--->", e)
            print("edges_out", interval)
            for e in edges_out:
                print("-->", e)
            print("pending out", interval)
            for e in pending_out:
                print("--->", e)
        edges_out.extend(pending_out)
        edges_in.extend(pending_in)
        pending_out = []
        pending_in = []
        extended = [False for _ in edges_out]
        for j1, e1 in reversed(list(enumerate(edges_out))):
            # assert last_tree.parent(e1.child) == e1.parent
            if not extended[j1]:
                for j2, e2 in reversed(list(enumerate(edges_out))):
                    if not extended[j2]:
                        if e1.parent == e2.child:
                            for e_in in reversed(edges_in):
                                if e_in.right > interval.left:
                                    # assert next_tree.parent(e_in.child) == e_in.parent
                                    if e1.child == e_in.child and e2.parent == e_in.parent:
                                        # print("     ", interval, e1.child, "-", e1.parent, "-", e2.parent, " -> ", e_in)
                                        max_n -= 1
                                        if max_n <= 0:
                                            assert False
                                        print("ping++", e1.id, "+", e2.id, "=", e_in.id)
                                        # extend e1 and e2, postpone e_in
                                        extended[j1] = True
                                        extended[j2] = True
                                        pending_out.extend([e1, e2])
                                        pending_in.append(e_in)
                                        new_right[e1.id] = interval.right
                                        new_right[e2.id] = interval.right
                                        new_left[e_in.id] = interval.right
                                        # TODO fix up this terrible flow control 
                                        # to make sure that the same edges aren't extended more than once
    
    keep = new_left < new_right
    edges.set_columns(
        left=new_left[keep],
        right=new_right[keep],
        parent=edges.parent[keep],
        child=edges.child[keep])
    new_ts = t.tree_sequence()
    return new_ts

# %%
nnew_ts = extend_edges_back_pass(ts)
print("----")
eets = extend_edges(ts)
print(ts.num_edges, nnew_ts.num_edges, eets.num_edges)
# Out:
# ping!! 1 + 9 = 8
# ping!! 1 + 9 = 8
# ping!! 8 + 13 = 11
# ping!! 8 + 13 = 11
# ping!! 8 + 13 = 11
# ping!! 25 + 33 = 30
# ping!! 8 + 13 = 11
# ping!! 27 + 34 = 29
# ----
# ping!! 1 + 9 = 8
# ping!! 1 + 9 = 8
# ping!! 8 + 13 = 11
# ping!! 8 + 13 = 11
# ping!! 8 + 13 = 11
# ping!! 25 + 33 = 30
# ping!! 8 + 13 = 11
# ping!! 27 + 34 = 29
# 35 32 32

# %%
def verify_extending_back_pass(ts):
    ets = extend_edges_back_pass(ts)
    sts = ets.simplify()
    sts.tables.assert_equals(ts.tables, ignore_provenance=True)
    print("old edges:", ts.num_edges, "new edges:", ets.num_edges)
    eets = extend_edges_back_pass(ets)
    
verify_extending_back_pass(ts)
# Out:
# ping!! 8 + 14 = 10
# old edges: 23 new edges: 22

# %%
for seed in range(1, 100):
    print("----", seed)
    ts = msprime.sim_ancestry(3, population_size=1000, sequence_length=1e5, recombination_rate=1e-8, random_seed=seed)
    ets = extend_edges(ts)
    bets = extend_edges_back_pass(ts)
    verify_extending_back_pass(ts)
    print('old alg num edges: ', ets.num_edges)
    if ets.num_edges != bets.num_edges:
        print()
        print('!!!!!!!!!!!!!!!!!DIFFERENT EDGE COUNT!!!!!!!!!!!!!!!!')
        print()
# Out:
# ---- 1
# ping!! 10 + 13 = 11
# ping!! 10 + 13 = 11
# ping!! 10 + 13 = 11
# old edges: 22 new edges: 21
# old alg num edges:  21
# ---- 2
# ping!! 3 + 6 = 5
# ping!! 5 + 11 = 7
# ping!! 0 + 10 = 9
# ping!! 5 + 11 = 7
# ping!! 0 + 10 = 9
# ping!! 5 + 11 = 7
# ping!! 0 + 10 = 9
# ping!! 5 + 11 = 7
# ping!! 29 + 38 = 32
# ping!! 26 + 45 = 41
# ping!! 15 + 43 = 39
# ping!! 5 + 11 = 7
# ping!! 15 + 43 = 39
# ping!! 5 + 11 = 7
# ping!! 0 + 10 = 9
# ping!! 5 + 11 = 7
# ping!! 0 + 10 = 9
# ping!! 5 + 11 = 7
# ping!! 0 + 10 = 9
# ping!! 5 + 11 = 7
# ping!! 29 + 38 = 32
# ping!! 26 + 45 = 41
# ping!! 15 + 43 = 39
# ping!! 5 + 11 = 7
# ping!! 15 + 43 = 39
# ping!! 5 + 11 = 7
# ping!! 0 + 10 = 9
# ping!! 5 + 11 = 7
# ping!! 0 + 10 = 9
# ping!! 5 + 11 = 7
# ping!! 0 + 10 = 9
# ping!! 5 + 11 = 7
# ping!! 29 + 38 = 32
# old edges: 62 new edges: 57
# old alg num edges:  57
# ---- 15
# ping!! 7 + 15 = 13
# ping!! 7 + 15 = 13
# ping!! 7 + 15 = 13
# ping!! 7 + 15 = 13
# ping!! 8 + 23 = 22
# ping!! 7 + 15 = 13
# ping!! 7 + 15 = 13
# ping!! 7 + 15 = 13
# ping!! 7 + 15 = 13
# ping!! 8 + 23 = 22
# ping!! 7 + 15 = 13
# ping!! 7 + 15 = 13
# ping!! 7 + 15 = 13
# ping!! 7 + 15 = 13
# ping!! 8 + 23 = 22
# old edges: 39 new edges: 37
# old alg num edges:  37
# ---- 16
# ping!! 4 + 9 = 6
# ping!! 13 + 34 = 32
# ping!! 4 + 9 = 6
# ping!! 4 + 9 = 6
# ping!! 4 + 9 = 6
# ping!! 2 + 8 = 7
# ping!! 4 + 9 = 6
# ping!! 2 + 8 = 7
# ping!! 4 + 9 = 6
# ping!! 2 + 8 = 7
# ping!! 4 + 9 = 6
# ping!! 2 + 8 = 7
# ping!! 4 + 9 = 6
# ping!! 2 + 8 = 7
# ping!! 4 + 9 = 6
# ping!! 4 + 9 = 6
# ping!! 13 + 34 = 32
# ping!! 4 + 9 = 6
# ping!! 4 + 9 = 6
# ping!! 4 + 9 = 6
# ping!! 2 + 8 = 7
# ping!! 4 + 9 = 6
# ping!! 2 + 8 = 7
# ping!! 4 + 9 = 6
# ping!! 2 + 8 = 7
# ping!! 4 + 9 = 6
# ping!! 2 + 8 = 7
# ping!! 4 + 9 = 6
# ping!! 2 + 8 = 7
# ping!! 4 + 9 = 6
# ping!! 4 + 9 = 6
# ping!! 13 + 34 = 32
# ping!! 4 + 9 = 6
# ping!! 4 + 9 = 6
# ping!! 4 + 9 = 6
# ping!! 2 + 8 = 7
# ping!! 4 + 9 = 6
# ping!! 2 + 8 = 7
# ping!! 4 + 9 = 6
# ping!! 2 + 8 = 7
# ping!! 4 + 9 = 6
# ping!! 2 + 8 = 7
# ping!! 4 + 9 = 6
# ping!! 2 + 8 = 7
# ping!! 4 + 9 = 6
# old edges: 36 new edges: 33
# old alg num edges:  33
# ---- 17
# ping!! 7 + 11 = 9
# ping!! 7 + 11 = 9
# ping!! 7 + 11 = 9
# old edges: 21 new edges: 20
# old alg num edges:  20
# ---- 18
# old edges: 16 new edges: 16
# old alg num edges:  16
# ---- 19
# ping!! 10 + 23 = 20
# ping!! 2 + 6 = 4
# ping!! 2 + 6 = 4
# ping!! 2 + 6 = 4
# ping!! 16 + 25 = 22
# ping!! 2 + 6 = 4
# ping!! 2 + 6 = 4
# ping!! 2 + 6 = 4
# ping!! 2 + 6 = 4
# ping!! 2 + 6 = 4
# ping!! 2 + 6 = 4
# ping!! 10 + 23 = 20
# ping!! 2 + 6 = 4
# ping!! 2 + 6 = 4
# ping!! 2 + 6 = 4
# ping!! 16 + 25 = 22
# ping!! 2 + 6 = 4
# ping!! 2 + 6 = 4
# ping!! 2 + 6 = 4
# ping!! 2 + 6 = 4
# ping!! 2 + 6 = 4
# ping!! 2 + 6 = 4
# ping!! 10 + 23 = 20
# ping!! 2 + 6 = 4
# ping!! 2 + 6 = 4
# ping!! 2 + 6 = 4
# ping!! 16 + 25 = 22
# ping!! 2 + 6 = 4
# ping!! 2 + 6 = 4
# ping!! 2 + 6 = 4
# ping!! 2 + 6 = 4
# ping!! 2 + 6 = 4
# ping!! 2 + 6 = 4
# old edges: 37 new edges: 34
# old alg num edges:  34
# ---- 20
# ping!! 1 + 9 = 8
# ping!! 1 + 9 = 8
# ping!! 8 + 13 = 11
# ping!! 8 + 13 = 11
# ping!! 8 + 13 = 11
# ping!! 25 + 33 = 30
# ping!! 8 + 13 = 11
# ping!! 27 + 34 = 29
# ping!! 1 + 9 = 8
# ping!! 1 + 9 = 8
# ping!! 8 + 13 = 11
# ping!! 8 + 13 = 11
# ping!! 8 + 13 = 11
# ping!! 25 + 33 = 30
# ping!! 8 + 13 = 11
# ping!! 27 + 34 = 29
# ping!! 1 + 9 = 8
# ping!! 1 + 9 = 8
# ping!! 8 + 13 = 11
# ping!! 8 + 13 = 11
# ping!! 8 + 13 = 11
# ping!! 25 + 33 = 30
# ping!! 8 + 13 = 11
# ping!! 27 + 34 = 29
# old edges: 35 new edges: 32
# ping!! 1 + 9 = 8
# ping!! 1 + 9 = 8
# ping!! 1 + 9 = 8
# ping!! 1 + 9 = 8
# old alg num edges:  32
# ---- 21
# ping!! 6 + 9 = 8
# ping!! 8 + 12 = 11
# ping!! 16 + 22 = 19
# ping!! 8 + 12 = 11
# ping!! 8 + 12 = 11
# ping!! 8 + 12 = 11
# ping!! 6 + 9 = 8
# ping!! 8 + 12 = 11
# ping!! 16 + 22 = 19
# ping!! 8 + 12 = 11
# ping!! 8 + 12 = 11
# ping!! 8 + 12 = 11
# ping!! 6 + 9 = 8
# ping!! 8 + 12 = 11
# ping!! 16 + 22 = 19
# ping!! 8 + 12 = 11
# ping!! 8 + 12 = 11
# ping!! 8 + 12 = 11
# old edges: 28 new edges: 26
# ping!! 6 + 9 = 8
# ping!! 6 + 9 = 8
# ping!! 6 + 9 = 8
# ping!! 6 + 9 = 8
# old alg num edges:  26
# ---- 22
# ping!! 6 + 17 = 16
# ping!! 4 + 12 = 11
# ping!! 6 + 17 = 16
# ping!! 4 + 12 = 11
# ping!! 4 + 12 = 11
# ping!! 6 + 17 = 16
# ping!! 4 + 12 = 11
# ping!! 6 + 17 = 16
# ping!! 4 + 12 = 11
# ping!! 4 + 12 = 11
# ping!! 6 + 17 = 16
# ping!! 4 + 12 = 11
# ping!! 6 + 17 = 16
# ping!! 4 + 12 = 11
# ping!! 4 + 12 = 11
# old edges: 28 new edges: 26
# old alg num edges:  26
# ---- 23
# ping!! 3 + 8 = 7
# ping!! 16 + 30 = 29
# ping!! 3 + 8 = 7
# ping!! 3 + 8 = 7
# ping!! 17 + 21 = 19
# ping!! 3 + 8 = 7
# ping!! 20 + 27 = 24
# ping!! 3 + 8 = 7
# ping!! 3 + 8 = 7
# ping!! 3 + 8 = 7
# ping!! 14 + 34 = 32
# ping!! 3 + 8 = 7
# ping!! 3 + 8 = 7
# ping!! 16 + 30 = 29
# ping!! 3 + 8 = 7
# ping!! 3 + 8 = 7
# ping!! 17 + 21 = 19
# ping!! 3 + 8 = 7
# ping!! 20 + 27 = 24
# ping!! 3 + 8 = 7
# ping!! 3 + 8 = 7
# ping!! 3 + 8 = 7
# ping!! 14 + 34 = 32
# ping!! 3 + 8 = 7
# ping!! 3 + 8 = 7
# ping!! 16 + 30 = 29
# ping!! 3 + 8 = 7
# ping!! 3 + 8 = 7
# ping!! 17 + 21 = 19
# ping!! 3 + 8 = 7
# ping!! 20 + 27 = 24
# ping!! 3 + 8 = 7
# ping!! 3 + 8 = 7
# ping!! 3 + 8 = 7
# ping!! 14 + 34 = 32
# ping!! 3 + 8 = 7
# old edges: 37 new edges: 32
# old alg num edges:  32
# ---- 24
# ping!! 9 + 21 = 20
# ping!! 4 + 20 = 19
# ping!! 9 + 21 = 20
# ping!! 4 + 20 = 19
# ping!! 9 + 21 = 20
# ping!! 4 + 20 = 19
# old edges: 23 new edges: 22
# ping!! 9 + 20 = 19
# old alg num edges:  22
# ---- 25
# ping!! 6 + 12 = 11
# ping!! 10 + 18 = 16
# ping!! 6 + 12 = 11
# ping!! 10 + 18 = 16
# ping!! 6 + 12 = 11
# ping!! 10 + 18 = 16
# old edges: 21 new edges: 19
# old alg num edges:  19
# ---- 26
# ping!! 14 + 24 = 21
# ping!! 14 + 24 = 21
# ping!! 9 + 32 = 30
# ping!! 28 + 37 = 35
# ping!! 14 + 24 = 21
# ping!! 14 + 24 = 21
# ping!! 9 + 32 = 30
# ping!! 28 + 37 = 35
# ping!! 14 + 24 = 21
# ping!! 14 + 24 = 21
# ping!! 9 + 32 = 30
# ping!! 28 + 37 = 35
# old edges: 38 new edges: 35
# old alg num edges:  35
# ---- 27
# ping!! 6 + 12 = 10
# ping!! 6 + 12 = 10
# ping!! 6 + 12 = 10
# old edges: 14 new edges: 13
# old alg num edges:  13
# ---- 28
# ping!! 14 + 23 = 21
# ping!! 14 + 23 = 21
# ping!! 10 + 28 = 26
# ping!! 10 + 28 = 26
# ping!! 14 + 23 = 21
# ping!! 14 + 23 = 21
# ping!! 10 + 28 = 26
# ping!! 10 + 28 = 26
# ping!! 14 + 23 = 21
# ping!! 14 + 23 = 21
# ping!! 10 + 28 = 26
# ping!! 10 + 28 = 26
# old edges: 38 new edges: 36
# old alg num edges:  36
# ---- 29
# ping!! 7 + 41 = 40
# ping!! 14 + 37 = 35
# ping!! 9 + 29 = 27
# ping!! 18 + 31 = 26
# ping!! 4 + 23 = 21
# ping!! 4 + 23 = 21
# ping!! 4 + 23 = 21
# ping!! 4 + 23 = 21
# ping!! 7 + 41 = 40
# ping!! 14 + 37 = 35
# ping!! 9 + 29 = 27
# ping!! 18 + 31 = 26
# ping!! 4 + 23 = 21
# ping!! 4 + 23 = 21
# ping!! 4 + 23 = 21
# ping!! 4 + 23 = 21
# ping!! 7 + 41 = 40
# ping!! 14 + 37 = 35
# ping!! 9 + 29 = 27
# ping!! 18 + 31 = 26
# ping!! 4 + 23 = 21
# ping!! 4 + 23 = 21
# ping!! 4 + 23 = 21
# ping!! 4 + 23 = 21
# old edges: 44 new edges: 39
# old alg num edges:  39
# ---- 30
# ping!! 2 + 17 = 15
# ping!! 10 + 22 = 21
# ping!! 10 + 22 = 21
# ping!! 10 + 22 = 21
# ping!! 2 + 17 = 15
# ping!! 10 + 22 = 21
# ping!! 10 + 22 = 21
# ping!! 10 + 22 = 21
# ping!! 2 + 17 = 15
# ping!! 10 + 22 = 21
# ping!! 10 + 22 = 21
# ping!! 10 + 22 = 21
# old edges: 36 new edges: 34
# old alg num edges:  34
# ---- 31
# ping!! 4 + 8 = 6
# ping!! 4 + 8 = 6
# ping!! 9 + 23 = 21
# ping!! 16 + 20 = 18
# ping!! 4 + 8 = 6
# ping!! 4 + 8 = 6
# ping!! 9 + 23 = 21
# ping!! 16 + 20 = 18
# ping!! 4 + 8 = 6
# ping!! 4 + 8 = 6
# ping!! 9 + 23 = 21
# ping!! 16 + 20 = 18
# old edges: 36 new edges: 33
# old alg num edges:  33
# ---- 32
# ping!! 6 + 14 = 12
# ping!! 6 + 14 = 12
# ping!! 6 + 14 = 12
# old edges: 22 new edges: 21
# old alg num edges:  21
# ---- 33
# ping!! 14 + 21 = 19
# ping!! 14 + 21 = 19
# ping!! 14 + 21 = 19
# ping!! 14 + 21 = 19
# ping!!
# ping!! 5 + 8 = 7
# ping!! 7 + 22 = 21
# ping!! 3 + 15 = 13
# ping!! 3 + 15 = 13
# ping!! 3 + 15 = 13
# ping!! 20 + 26 = 24
# ping!! 3 + 15 = 13
# old edges: 38 new edges: 34
# ping!! 11 + 15 = 14
# ping!! 5 + 8 = 7
# ping!! 11 + 15 = 14
# ping!! 11 + 15 = 14
# ping!! 11 + 15 = 14
# ping!! 11 + 15 = 14
# old alg num edges:  34
# ---- 41
# ping!! 1 + 18 = 16
# ping!! 15 + 30 = 29
# ping!! 1 + 18 = 16
# ping!! 1 + 18 = 16
# ping!! 1 + 18 = 16
# ping!! 1 + 18 = 16
# ping!! 12 + 43 = 42
# ping!! 1 + 18 = 16
# ping!! 1 + 18 = 16
# ping!! 19 + 38 = 36
# ping!! 1 + 18 = 16
# ping!! 15 + 30 = 29
# ping!! 1 + 18 = 16
# ping!! 1 + 18 = 16
# ping!! 1 + 18 = 16
# ping!! 1 + 18 = 16
# ping!! 12 + 43 = 42
# ping!! 1 + 18 = 16
# ping!! 1 + 18 = 16
# ping!! 19 + 38 = 36
# ping!! 1 + 18 = 16
# ping!! 15 + 30 = 29
# ping!! 1 + 18 = 16
# ping!! 1 + 18 = 16
# ping!! 1 + 18 = 16
# ping!! 1 + 18 = 16
# ping!! 12 + 43 = 42
# ping!! 1 + 18 = 16
# ping!! 1 + 18 = 16
# ping!! 19 + 38 = 36
# old edges: 45 new edges: 41
# old alg num edges:  41
# ---- 42
# ping!! 10 + 14 = 13
# ping!! 10 + 14 = 13
# ping!! 10 + 14 = 13
# ping!! 10 + 14 = 13
# ping!! 12 + 23 = 19
# ping!! 10 + 14 = 13
# ping!! 10 + 14 = 13
# ping!! 10 + 14 = 13
# ping!! 10 + 14 = 13
# ping!! 12 + 23 = 19
# ping!! 10 + 14 = 13
# ping!! 10 + 14 = 13
# ping!! 10 + 14 = 13
# ping!! 10 + 14 = 13
# ping!! 12 + 23 = 19
# old edges: 28 new edges: 26
# old alg num edges:  26
# ---- 43
# ping!! 3 + 8 = 7
# ping!! 3 + 8 = 7
# ping!! 3 + 8 = 7
# ping!! 3 + 8 = 7
# ping!! 3 + 8 = 7
# ping!! 3 + 8 = 7
# old edges: 19 new edges: 18
# old alg num edges:  18
# ---- 44
# ping!! 7 + 12 = 10
# ping!! 7 + 12 = 10
# ping!! 7 + 12 = 10
# old edges: 22 new edges: 21
# old alg num edges:  21
# ---- 45
# ping!! 9 + 21 = 19
# ping!! 9 + 21 = 19
# ping!! 9 + 21 = 19
# old edges: 23 new edges: 22
# old alg num edges:  22
# ---- 46
# ping!! 7 + 15 = 14
# ping!! 5 + 21 = 20
# ping!! 5 + 21 = 20
# ping!! 7 + 15 = 14
# ping!! 5 + 21 = 20
# ping!! 5 + 21 = 20
# ping!! 7 + 15 = 14
# ping!! 5 + 21 = 20
# ping!! 5 + 21 = 20
# old edges: 25 new edges: 23
# old alg num edges:  23
# ---- 47
# ping!! 8 + 11 = 10
# ping!! 8 + 11 = 10
# ping!! 8 + 11 = 10
# old edges: 26 new edges: 25
# old alg num edges:  25
# ---- 48
# ping!! 23 + 35 = 27
# ping!! 26 + 36 = 30
# ping!! 10 + 38 = 37
# ping!! 10 + 38 = 37
# ping!! 23 + 35 = 27
# ping!! 26 + 36 = 30
# ping!! 10 + 38 = 37
# ping!! 10 + 38 = 37
# ping!! 23 + 35 = 27
# ping!! 26 + 36 = 30
# ping!! 10 + 38 = 37
# ping!! 10 + 38 = 37
# old edges: 47 new edges: 44
# old alg num edges:  44
# ---- 49
# old edges: 20 new edges: 20
# old alg num edges:  20
# ---- 50
# ping!! 6 + 13 = 11
# ping!! 22 + 31 = 28
# ping!! 6 + 13 = 11
# ping!! 9 + 26 = 25
# ping!! 6 + 13 = 11
# ping!! 4 + 25 = 23
# ping!! 12 + 18 = 17
# ping!! 6 + 13 = 11
# ping!! 22 + 31 = 28
# ping!! 6 + 13 = 11
# ping!! 9 + 26 = 25
# ping!! 6 + 13 = 11
# ping!! 4 + 25 = 23
# ping!! 12 + 18 = 17
# ping!! 6 + 13 = 11
# ping!! 22 + 31 = 28
# ping!! 6 + 13 = 11
# ping!! 9 + 26 = 25
# ping!! 6 + 13 = 11
# ping!! 4 + 25 = 23
# ping!! 12 + 18 = 17
# old edges: 34 new edges: 30
# ping!! 9 + 23 = 22
# old alg num edges:  30
# ---- 51
# ping!! 6 + 14 = 13
# ping!! 15 + 20 = 19
# ping!! 6 + 14 = 13
# ping!! 15 + 20 = 19
# ping!! 6 + 14 = 13
# ping!! 15 + 20 = 19
# old edges: 23 new edges: 21
# old alg num edges:  21
# ---- 52
# ping!! 14 + 19 = 18
# ping!! 14 + 19 = 18
# ping!! 14 + 19 = 18
# old edges: 34 new edges: 33
# old alg num edges:  33
# ---- 53
# ping!! 13 + 48 = 44
# ping!! 15 + 49 = 47
# ping!! 15 + 49 = 47
# ping!! 39 + 54 = 41
# ping!! 11 + 37 = 35
# ping!! 39 + 54 = 41
# ping!! 25 + 38 = 34
# ping!! 11 + 37 = 35
# ping!! 25 + 38 = 34
# ping!! 11 + 37 = 35
# ping!! 34 + 60 = 55
# ping!! 21 + 33 = 31
# ping!! 26 + 51 = 43
# ping!! 21 + 33 = 31
# ping!! 21 + 33 = 31
# ping!! 21 + 33 = 31
# ping!! 32 + 67 = 64
# ping!! 29 + 66 = 62
# ping!! 32 + 67 = 64
# ping!! 29 + 66 = 62
# ping!! 32 + 67 = 64
# ping!! 19 + 64 = 63
# ping!! 13 + 48 = 44
# ping!! 15 + 49 = 47
# ping!! 15 + 49 = 47
# ping!! 39 + 54 = 41
# ping!! 11 + 37 = 35
# ping!! 39 + 54 = 41
# ping!! 25 + 38 = 34
# ping!! 11 + 37 = 35
# ping!! 25 + 38 = 34
# ping!! 11 + 37 = 35
# ping!! 34 + 60 = 55
# ping!! 21 + 33 = 31
# ping!! 26 + 51 = 43
# ping!! 21 + 33 = 31
# ping!! 21 + 33 = 31
# ping!! 21 + 33 = 31
# ping!! 32 + 67 = 64
# ping!! 29 + 66 = 62
# ping!! 32 + 67 = 64
# ping!! 29 + 66 = 62
# ping!! 32 + 67 = 64
# ping!! 19 + 64 = 63
# ping!! 13 + 48 = 44
# ping!! 15 + 49 = 47
# ping!! 15 + 49 = 47
# ping!! 39 + 54 = 41
# ping!! 11 + 37 = 35
# ping!! 39 + 54 = 41
# ping!! 25 + 38 = 34
# ping!! 11 + 37 = 35
# ping!! 25 + 38 = 34
# ping!! 11 + 37 = 35
# ping!! 34 + 60 = 55
# ping!! 21 + 33 = 31
# ping!! 26 + 51 = 43
# ping!! 21 + 33 = 31
# ping!! 21 + 33 = 31
# ping!! 21 + 33 = 31
# ping!! 32 + 67 = 64
# ping!! 29 + 66 = 62
# ping!! 32 + 67 = 64
# ping!! 29 + 66 = 62
# ping!! 32 + 67 = 64
# ping!! 19 + 64 = 63
# old edges: 68 new edges: 59
# ping!! 25 + 36 = 33
# ping!! 31 + 58 = 55
# old alg num edges:  59
# ---- 54
# ping!! 7 + 11 = 9
# ping!! 7 + 11 = 9
# ping!! 7 + 11 = 9
# ping!! 13 + 18 = 17
# ping!! 7 + 11 = 9
# ping!! 13 + 18 = 17
# ping!! 7 + 11 = 9
# ping!! 13 + 18 = 17
# ping!! 7 + 11 = 9
# ping!!
+ 25 = 22
# ping!! 2 + 6 = 4
# ping!! 4 + 9 = 7
# ping!! 11 + 25 = 22
# ping!! 27 + 34 = 33
# ping!! 4 + 9 = 7
# ping!! 13 + 18 = 14
# ping!! 13 + 18 = 14
# ping!! 16 + 26 = 23
# ping!! 2 + 6 = 4
# ping!! 16 + 26 = 23
# ping!! 11 + 25 = 22
# ping!! 2 + 6 = 4
# ping!! 11 + 25 = 22
# ping!! 2 + 6 = 4
# ping!! 4 + 9 = 7
# ping!! 11 + 25 = 22
# ping!! 27 + 34 = 33
# ping!! 4 + 9 = 7
# ping!! 13 + 18 = 14
# ping!! 13 + 18 = 14
# ping!! 16 + 26 = 23
# ping!! 2 + 6 = 4
# ping!! 16 + 26 = 23
# ping!! 11 + 25 = 22
# ping!! 2 + 6 = 4
# ping!! 11 + 25 = 22
# ping!! 2 + 6 = 4
# ping!! 4 + 9 = 7
# ping!! 11 + 25 = 22
# ping!! 27 + 34 = 33
# ping!! 4 + 9 = 7
# old edges: 36 new edges: 31
# ping!! 2 + 6 = 4
# ping!! 2 + 6 = 4
# old alg num edges:  31
# ---- 60
# ping!! 10 + 13 = 12
# ping!! 10 + 13 = 12
# ping!! 10 + 13 = 12
# old edges: 18 new edges: 17
# old alg num edges:  17
# ---- 61
# old edges: 14 new edges: 14
# old alg num edges:  14
# ---- 62
# ping!! 12 + 19 = 16
# ping!! 5 + 10 = 9
# ping!! 5 + 10 = 9
# ping!! 12 + 19 = 16
# ping!! 5 + 10 = 9
# ping!! 5 + 10 = 9
# ping!! 12 + 19 = 16
# ping!! 5 + 10 = 9
# ping!! 5 + 10 = 9
# old edges: 26 new edges: 24
# old alg num edges:  24
# ---- 63
# old edges: 15 new edges: 15
# old alg num edges:  15
# ---- 64
# ping!! 4 + 10 = 8
# ping!! 4 + 10 = 8
# ping!! 6 + 17 = 15
# ping!! 4 + 10 = 8
# ping!! 18 + 22 = 20
# ping!! 4 + 10 = 8
# ping!! 4 + 10 = 8
# ping!! 4 + 10 = 8
# ping!! 6 + 17 = 15
# ping!! 4 + 10 = 8
# ping!! 18 + 22 = 20
# ping!! 4 + 10 = 8
# ping!! 4 + 10 = 8
# ping!! 4 + 10 = 8
# ping!! 6 + 17 = 15
# ping!! 4 + 10 = 8
# ping!! 18 + 22 = 20
# ping!! 4 + 10 = 8
# old edges: 27 new edges: 24
# old alg num edges:  24
# ---- 65
# ping!! 8 + 30 = 27
# ping!! 1 + 4 = 3
# ping!! 11 + 24 = 20
# ping!! 1 + 4 = 3
# ping!! 16 + 26 = 23
# ping!! 1 + 4 = 3
# ping!! 13 + 25 = 21
# ping!! 16 + 26 = 23
# ping!! 1 + 4 = 3
# ping!! 18 + 32 = 29
# ping!! 13 + 25 = 21
# ping!! 16 + 26 = 23
# ping!! 1 + 4 = 3
# ping!! 13 + 25 = 21
# ping!! 16 + 26 = 23
# ping!! 1 + 4 = 3
# ping!! 33 + 38 = 37
# ping!! 13 + 25 = 21
# ping!! 16 + 26 = 23
# ping!! 1 + 4 = 3
# ping!! 8 + 30 = 27
# ping!! 1 + 4 = 3
# ping!! 11 + 24 = 20
# ping!! 1 + 4 = 3
# ping!! 16 + 26 = 23
# ping!! 1 + 4 = 3
# ping!! 13 + 25 = 21
# ping!! 16 + 26 = 23
# ping!! 1 + 4 = 3
# ping!! 18 + 32 = 29
# ping!! 13 + 25 = 21
# ping!! 16 + 26 = 23
# ping!! 1 + 4 = 3
# ping!! 13 + 25 = 21
# ping!! 16 + 26 = 23
# ping!! 1 + 4 = 3
# ping!! 33 + 38 = 37
# ping!! 13 + 25 = 21
# ping!! 16 + 26 = 23
# ping!! 1 + 4 = 3
# ping!! 8 + 30 = 27
# ping!! 1 + 4 = 3
# ping!! 11 + 24 = 20
# ping!! 1 + 4 = 3
# ping!! 16 + 26 = 23
# ping!! 1 + 4 = 3
# ping!! 13 + 25 = 21
# ping!! 16 + 26 = 23
# ping!! 1 + 4 = 3
# ping!! 18 + 32 = 29
# ping!! 13 + 25 = 21
# ping!! 16 + 26 = 23
# ping!! 1 + 4 = 3
# ping!! 13 + 25 = 21
# ping!! 16 + 26 = 23
# ping!! 1 + 4 = 3
# ping!! 33 + 38 = 37
# ping!! 13 + 25 = 21
# ping!! 16 + 26 = 23
# ping!! 1 + 4 = 3
# old edges: 40 new edges: 33
# old alg num edges:  33
# ---- 66
# ping!! 7 + 12 = 11
# ping!! 11 + 20 = 18
# ping!! 11 + 20 = 18
# ping!! 1 + 29 = 28
# ping!! 11 + 20 = 18
# ping!! 18 + 32 = 30
# ping!! 8 + 26 = 24
# ping!! 7 + 12 = 11
# ping!! 11 + 20 = 18
# ping!! 11 + 20 = 18
# ping!! 1 + 29 = 28
# ping!! 11 + 20 = 18
# ping!! 18 + 32 = 30
# ping!! 8 + 26 = 24
# ping!! 24 + 31 = 30
# old edges: 58 new edges: 54
# old alg num edges:  54
# ---- 72
# ping!! 5 + 15 = 12
# ping!! 5 + 15 = 12
# ping!! 22 + 34 = 31
# ping!! 22 + 34 = 31
# ping!! 18 + 27 = 24
# ping!! 18 + 27 = 24
# ping!! 5 + 15 = 12
# ping!! 5 + 15 = 12
# ping!! 22 + 34 = 31
# ping!! 22 + 34 = 31
# ping!! 18 + 27 = 24
# ping!! 18 + 27 = 24
# ping!! 5 + 15 = 12
# ping!! 5 + 15 = 12
# ping!! 22 + 34 = 31
# ping!! 22 + 34 = 31
# ping!! 18 + 27 = 24
# ping!! 18 + 27 = 24
# old edges: 41 new edges: 38
# old alg num edges:  38
# ---- 73
# old edges: 21 new edges: 21
# old alg num edges:  21
# ---- 74
# ping!! 2 + 11 = 8
# ping!! 2 + 11 = 8
# ping!! 2 + 11 = 8
# ping!! 2 + 11 = 8
# ping!! 2 + 11 = 8
# ping!! 2 + 11 = 8
# ping!! 2 + 11 = 8
# ping!! 2 + 11 = 8
# ping!! 2 + 11 = 8
# ping!! 2 + 11 = 8
# ping!! 2 + 11 = 8
# ping!! 2 + 11 = 8
# old edges: 32 new edges: 31
# old alg num edges:  31
# ---- 75
# ping!! 13 + 17 = 15
# ping!! 13 + 17 = 15
# ping!! 13 + 17 = 15
# ping!! 11 + 16 = 14
# ping!! 13 + 17 = 15
# ping!! 13 + 17 = 15
# ping!! 13 + 17 = 15
# ping!! 13 + 17 = 15
# ping!! 11 + 16 = 14
# ping!! 13 + 17 = 15
# ping!! 13 + 17 = 15
# ping!! 13 + 17 = 15
# ping!! 13 + 17 = 15
# ping!! 11 + 16 = 14
# ping!! 13 + 17 = 15
# old edges: 22 new edges: 20
# old alg num edges:  20
# ---- 76
# ping!! 4 + 8 = 6
# ping!! 4 + 8 = 6
# ping!! 4 + 8 = 6
# old edges: 18 new edges: 17
# old alg num edges:  17
# ---- 77
# ping!! 5 + 16 = 14
# ping!! 5 + 16 = 14
# ping!! 5 + 16 = 14
# old edges: 20 new edges: 19
# old alg num edges:  19
# ---- 78
# ping!! 7 + 11 = 10
# ping!! 7 + 11 = 10
# ping!! 7 + 11 = 10
# ping!! 5 + 10 = 9
# ping!! 5 + 10 = 9
# ping!! 5 + 10 = 9
# ping!! 5 + 10 = 9
# ping!! 8 + 20 = 19
# ping!! 8 + 20 = 19
# ping!! 7 + 11 = 10
# ping!! 7 + 11 = 10
# ping!! 7 + 11 = 10
# ping!! 5 + 10 = 9
# ping!! 5 + 10 = 9
# ping!! 5 + 10 = 9
# ping!! 5 + 10 = 9
# ping!! 8 + 20 = 19
# ping!! 8 + 20 = 19
# ping!! 7 + 11 = 10
# ping!! 7 + 11 = 10
# ping!! 7 + 11 = 10
# ping!! 5 + 10 = 9
# ping!! 5 + 10 = 9
# ping!! 5 + 10 = 9
# ping!! 5 + 10 = 9
# ping!! 8 + 20 = 19
# ping!! 8 + 20 = 19
# old edges: 40 new edges: 38
# ping!! 7 + 10 = 9
# ping!! 7 + 10 = 9
# ping!! 7 + 10 = 9
# ping!! 7 + 10 = 9
# old alg num edges:  38
# ---- 79
# ping!! 10 + 13 = 12
# ping!! 6 + 10 = 9
# ping!! 10 + 13 = 12
# ping!! 6 + 10 = 9
# ping!! 10 + 13 = 12
# ping!! 6 + 10 = 9
# old edges: 19 new edges: 17
# old alg num edges:  17
# ---- 80
# ping!! 0 + 9 = 6
# ping!! 3 + 10 = 8
# ping!! 0 + 9 = 6
# ping!! 3 + 10 = 8
# ping!! 0 + 9 = 6
# ping!! 8 + 13 = 12
# ping!! 8 + 13 = 12
# ping!! 8 + 13 = 12
# ping!! 0 + 9 = 6
# ping!! 3 + 10 = 8
# ping!! 0 + 9 = 6
# ping!! 3 + 10 = 8
# ping!! 0 + 9 = 6
# ping!! 8 + 13 = 12
# ping!! 8 + 13 = 12
# ping!! 8 + 13 = 12
# ping!! 0 + 9 = 6
# ping!! 3 + 10 = 8
# ping!! 0 + 9 = 6
# ping!! 3 + 10 = 8
# ping!! 0 + 9 = 6
# ping!! 8 + 13 = 12
# ping!! 8 + 13 = 12
# ping!! 8 + 13 = 12
# old edges: 30 new edges: 28
# ping!! 3 + 9 = 7
# ping!! 3 + 9 = 7
# ping!! 3 + 9 = 7
# old alg num edges:  28
# ---- 81
# ping!! 6 + 12 = 8
# ping!! 6 + 12 = 8
# ping!! 6 + 12 = 8
# old edges: 19 new edges: 18
# old alg num edges:  18
# ---- 82
# ping!! 4 + 8 = 6
# ping!! 4 + 8 = 6
# ping!! 4 + 8 = 6
# ping!! 4 + 8 = 6
# ping!! 4 + 8 = 6
# ping!! 18 + 24 = 22
# ping!! 10 + 19 = 16
# old edges: 32 new edges: 30
# old alg num edges:  30
# ---- 89
# ping!! 10 + 22 = 18
# ping!! 12 + 31 = 24
# ping!! 8 + 29 = 26
# ping!! 10 + 22 = 18
# ping!! 12 + 31 = 24
# ping!! 8 + 29 = 26
# ping!! 10 + 22 = 18
# ping!! 12 + 31 = 24
# ping!! 8 + 29 = 26
# old edges: 34 new edges: 31
# old alg num edges:  31
# ---- 90
# ping!! 8 + 19 = 17
# ping!! 21 + 39 = 37
# ping!! 21 + 39 = 37
# ping!! 24 + 34 = 31
# ping!! 6 + 18 = 16
# ping!! 23 + 33 = 32
# ping!! 6 + 18 = 16
# ping!! 8 + 19 = 17
# ping!! 21 + 39 = 37
# ping!! 21 + 39 = 37
# ping!! 24 + 34 = 31
# ping!! 6 + 18 = 16
# ping!! 23 + 33 = 32
# ping!! 6 + 18 = 16
# ping!! 8 + 19 = 17
# ping!! 21 + 39 = 37
# ping!! 21 + 39 = 37
# ping!! 24 + 34 = 31
# ping!! 6 + 18 = 16
# ping!! 23 + 33 = 32
# ping!! 6 + 18 = 16
# old edges: 41 new edges: 36
# old alg num edges:  36
# ---- 91
# ping!! 8 + 11 = 10
# ping!! 16 + 32 = 31
# ping!! 8 + 11 = 10
# ping!! 9 + 20 = 18
# ping!! 16 + 32 = 31
# ping!! 19 + 29 = 25
# ping!! 16 + 32 = 31
# ping!! 19 + 29 = 25
# ping!! 19 + 29 = 25
# ping!! 19 + 29 = 25
# ping!! 19 + 29 = 25
# ping!! 2 + 6 = 5
# ping!! 19 + 29 = 25
# ping!! 8 + 11 = 10
# ping!! 16 + 32 = 31
# ping!! 8 + 11 = 10
# ping!! 9 + 20 = 18
# ping!! 16 + 32 = 31
# ping!! 19 + 29 = 25
# ping!! 16 + 32 = 31
# ping!! 19 + 29 = 25
# ping!! 19 + 29 = 25
# ping!! 19 + 29 = 25
# ping!! 19 + 29 = 25
# ping!! 2 + 6 = 5
# ping!! 19 + 29 = 25
# ping!! 8 + 11 = 10
# ping!! 16 + 32 = 31
# ping!! 8 + 11 = 10
# ping!! 9 + 20 = 18
# ping!! 16 + 32 = 31
# ping!! 19 + 29 = 25
# ping!! 16 + 32 = 31
# ping!! 19 + 29 = 25
# ping!! 19 + 29 = 25
# ping!! 19 + 29 = 25
# ping!! 19 + 29 = 25
# ping!! 2 + 6 = 5
# ping!! 19 + 29 = 25
# old edges: 45 new edges: 40
# old alg num edges:  40
# ---- 92
# ping!! 5 + 11 = 10
# ping!! 5 + 11 = 10
# ping!! 12 + 20 = 18
# ping!! 5 + 11 = 10
# ping!! 5 + 11 = 10
# ping!! 12 + 20 = 18
# ping!! 5 + 11 = 10
# ping!! 5 + 11 = 10
# ping!! 12 + 20 = 18
# old edges: 23 new edges: 21
# old alg num edges:  21
# ---- 93
# old edges: 14 new edges: 14
# old alg num edges:  14
# ---- 94
# ping!! 6 + 25 = 23
# ping!! 23 + 32 = 29
# ping!! 10 + 16 = 12
# ping!! 10 + 16 = 12
# ping!! 6 + 25 = 23
# ping!! 23 + 32 = 29
# ping!! 10 + 16 = 12
# ping!! 10 + 16 = 12
# ping!! 6 + 25 = 23
# ping!! 23 + 32 = 29
# ping!! 10 + 16 = 12
# ping!! 10 + 16 = 12
# old edges: 33 new edges: 31
# ping!! 6 + 24 = 22
# old alg num edges:  31
# ---- 95
# ping!! 7 + 10 = 8
# ping!! 14 + 18 = 17
# ping!! 7 + 10 = 8
# ping!! 7 + 10 = 8
# ping!! 14 + 18 = 17
# ping!! 7 + 10 = 8
# ping!! 7 + 10 = 8
# ping!! 14 + 18 = 17
# ping!! 7 + 10 = 8
# old edges: 21 new edges: 19
# old alg num edges:  19
# ---- 96
# ping!! 4 + 23 = 22
# ping!! 4 + 23 = 22
# ping!! 4 + 23 = 22
# old edges: 28 new edges: 27
# old alg num edges:  27
# ---- 97
# old edges: 12 new edges: 12
# old alg num edges:  12
# ---- 98
# ping!! 10 + 16 = 14
# ping!! 10 + 16 = 14
# ping!! 8 + 21 = 17
# ping!! 13 + 22 = 19
# ping!! 10 + 16 = 14
# ping!! 10 + 16 = 14
# ping!! 8 + 21 = 17
# ping!! 13 + 22 = 19
# ping!! 10 + 16 = 14
# ping!! 10 + 16 = 14
# ping!! 8 + 21 = 17
# ping!! 13 + 22 = 19
# old edges: 28 new edges: 25
# old alg num edges:  25
# ---- 99
# ping!! 8 + 14 = 10
# ping!! 8 + 14 = 10
# ping!! 8 + 14 = 10
# old edges: 23 new edges: 22
# old alg num edges:  22

# %% [markdown]
# We see from running this algorithm over many trees that adding a back pass for our algorithm does not reduce edges. We should run our algorithm on more tree sequences to see if it will be useful or not.

# %%
old_edge = ts.num_edges
est = extend_edges_back_pass(ts)
new_edge = est.num_edges
print(old_edge, new_edge)
while old_edge > new_edge:
    old_edge = new_edge
    nest = extend_edges_back_pass(est)
    update_edge = nest.num_edges
    new_edge = update_edge
    
else:
    print('simplified tree sequence:\n', nest)
# Out:
# ping!! 8 + 14 = 10
# 23 22
# simplified tree sequence:
#  ╔═══════════════════════════╗
# ║TreeSequence               ║
# ╠═══════════════╤═══════════╣
# ║Trees          │          6║
# ╟───────────────┼───────────╢
# ║Sequence Length│     100000║
# ╟───────────────┼───────────╢
# ║Time Units     │generations║
# ╟───────────────┼───────────╢
# ║Sample Nodes   │          6║
# ╟───────────────┼───────────╢
# ║Total Size     │    2.5 KiB║
# ╚═══════════════╧═══════════╝
# ╔═══════════╤════╤═════════╤════════════╗
# ║Table      │Rows│Size     │Has Metadata║
# ╠═══════════╪════╪═════════╪════════════╣
# ║Edges      │  22│712 Bytes│          No║
# ╟───────────┼────┼─────────┼────────────╢
# ║Individuals│   3│108 Bytes│          No║
# ╟───────────┼────┼─────────┼────────────╢
# ║Migrations │   0│  8 Bytes│          No║
# ╟───────────┼────┼─────────┼────────────╢
# ║Mutations  │   0│ 16 Bytes│          No║
# ╟───────────┼────┼─────────┼────────────╢
# ║Nodes      │  15│428 Bytes│          No║
# ╟───────────┼────┼─────────┼────────────╢
# ║Populations│   1│224 Bytes│         Yes║
# ╟───────────┼────┼─────────┼────────────╢
# ║Provenances│   1│898 Bytes│          No║
# ╟───────────┼────┼─────────┼────────────╢
# ║Sites      │   0│ 16 Bytes│          No║
# ╚═══════════╧════╧═════════╧════════════╝
