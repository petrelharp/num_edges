# %%
import msprime, tskit
from IPython.display import SVG
import numpy as np
import matplotlib.pyplot as plt
import COPYtest_extend_paths as ee

# %%
ts = msprime.sim_ancestry(3, population_size=1000, sequence_length=1e6, recombination_rate=1e-8, random_seed=40,
                          record_full_arg=True)

# %%
sts = ts.simplify()
new_sts = ts.simplify(keep_unary=True)
ext_sts, _ = extend_edges(sts)

# %%
print("Number of edges:")
print(f" simplified: {sts.num_edges}")
print(f" keep unary: {new_sts.num_edges}")
print(f"   extended: {ext_sts.num_edges}")
# Out:
# Number of edges:
#  simplified: 145
#  keep unary: 1079
#    extended: 125

# %% [markdown]
# # With 6 samples and 1e6 bp

# %%
res = []
for ts in msprime.sim_ancestry(3, population_size=1000, sequence_length=1e6, recombination_rate=1e-8, random_seed=40,
                          record_full_arg=True, num_replicates=100):
    sts = ts.simplify()
    new_sts = ts.simplify(keep_unary=True)
    ext_sts = ee.extend_paths(sts,10000)
    res.append((sts.num_edges, new_sts.num_edges, ext_sts.num_edges))

# %%
res = np.array(res)
x = np.argsort(np.argsort(res[:, 0]))

fig, ax = plt.subplots(figsize=(10,7))

ax.scatter(x, res[:, 0], label='simplified')
ax.scatter(x, res[:, 1], label='keep unary')
ax.scatter(x, res[:, 2], label='path extended')
ax.legend();

# %% [markdown]
# # With 2000 samples

# %%
res = []
for ts in msprime.sim_ancestry(1000, population_size=1000, sequence_length=1e6, recombination_rate=1e-8, random_seed=40,
                          record_full_arg=True, num_replicates=20):
    sts = ts.simplify()
    new_sts = ts.simplify(keep_unary=True)
    ext_sts, _ = ee.extend_paths(sts)
    res.append((sts.num_edges, new_sts.num_edges, ext_sts.num_edges))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 6
#       4 sts = ts.simplify()
#       5 new_sts = ts.simplify(keep_unary=True)
# ----> 6 ext_sts, _ = ee.extend_paths(sts)
#       7 res.append((sts.num_edges, new_sts.num_edges, ext_sts.num_edges))
#
# File ~/num_edges/num_edges/COPYtest_extend_paths.py:431, in extend_paths(ts, max_iter)
#     426 for forwards in [True, False]:
#     427     # for t in ts.trees():
#     428     #     print("------", t.interval)
#     429     #     print(t.draw_text())
#     430     extender = PathExtender(ts, forwards=forwards)
# --> 431     extender.extend_paths()
#     432     tables.edges.replace_with(extender.edges)
#     433     tables.sort()
#
# File ~/num_edges/num_edges/COPYtest_extend_paths.py:390, in PathExtender.extend_paths(self)
#     388 here = left if self.forwards else right
#     389 self.next_tree(tree_pos)
# --> 390 self.check_state(here)
#     391 for e_in, _ in self.edges_in:
#     392     c = self.edges[e_in].child
#
# File ~/num_edges/num_edges/COPYtest_extend_paths.py:257, in PathExtender.check_state(self, here)
#     255     assert self.near_side[e] != self.far_side[e]
#     256 self.check_state_at(here, False, self.next_degree, self.next_nodes_edge)
# --> 257 self.check_state_at(here, True, self.last_degree, self.last_nodes_edge)
#     258 self.check_parent(self.parent_in, [j for j, x in self.edges_in if x == 0])
#     259 self.check_parent(self.parent_out, [j for j, x in self.edges_out if x == 0])
#
# File ~/num_edges/num_edges/COPYtest_extend_paths.py:226, in PathExtender.check_state_at(self, pos, before, degree, nodes_edge)
#     224 assert len(self.near_side) == self.edges.num_rows
#     225 assert len(self.far_side) == self.edges.num_rows
# --> 226 for j, (e, l, r) in enumerate(zip(self.edges, self.near_side, self.far_side)):
#     227     overlaps = (l != r) and (
#     228         ((pos - l) * (r - pos) > 0)
#     229         or (r == pos and before)
#     230         or (l == pos and not before)
#     231     )
#     232     if overlaps:
#
# File ~/.local/lib/python3.9/site-packages/tskit/tables.py:516, in BaseTable.__getitem__(self, index)
#     514     if index < 0 or index >= len(self):
#     515         raise IndexError("Index out of bounds")
# --> 516     return self._make_row(*self.ll_table.get_row(index))
#     517 elif isinstance(index, numbers.Number):
#     518     raise TypeError("Index must be integer, slice or iterable")
#
# File ~/.local/lib/python3.9/site-packages/tskit/tables.py:714, in MetadataTable._make_row(self, *args)
#     713 def _make_row(self, *args):
# --> 714     return self.row_class(*args, metadata_decoder=self.metadata_schema.decode_row)
#
# File ~/.local/lib/python3.9/site-packages/tskit/metadata.py:782, in lazy_decode.<locals>._lazy_decode.<locals>.new_init(self, metadata_decoder, *args, **kwargs)
#     778 def new_init(self, *args, metadata_decoder=None, **kwargs):
#     779     __builtins__object__setattr__(
#     780         self, "_metadata_decoder", metadata_decoder
#     781     )
# --> 782     wrapped_init(self, *args, **kwargs)
#
# File <string>:7, in __init__(self, left, right, parent, child, metadata)
#
# File ~/.local/lib/python3.9/site-packages/tskit/metadata.py:763, in _CachedMetadata.__set__(self, row, value)
#     760         __builtins__object__setattr__(row, "_metadata_decoder", None)
#     761     return row._metadata
# --> 763 def __set__(self, row, value):
#     764     __builtins__object__setattr__(row, "_metadata", value)
#
# KeyboardInterrupt:

# %%
res = np.array(res)
x = np.argsort(np.argsort(res[:, 0]))

fig, ax = plt.subplots(figsize=(10,7))

ax.scatter(x, res[:, 0], label='simplified')
ax.scatter(x, res[:, 1], label='keep unary')
ax.scatter(x, res[:, 2], label='extended')
ax.legend();

# %% [markdown]
# # With 2000 samples and a genome of 1e7 bp

# %%
res = []
for ts in msprime.sim_ancestry(1000, population_size=1000, sequence_length=1e7, recombination_rate=1e-8, random_seed=40,
                          record_full_arg=True, num_replicates=4):
    sts = ts.simplify()
    new_sts = ts.simplify(keep_unary_if_coalescent=True)
    ext_sts, _ = extend_edges(sts)
    res.append((sts.num_edges, new_sts.num_edges, ext_sts.num_edges))

# %%
res = np.array(res)
x = np.argsort(np.argsort(res[:, 0]))

fig, ax = plt.subplots(figsize=(10,7))

ax.scatter(x, res[:, 0], label='simplified')
ax.scatter(x, res[:, 1], label='keep unary')
ax.scatter(x, res[:, 2], label='extended')
ax.legend();

# %% [markdown]
# # Experiment

# %%
res = {}
for num_samples in [10, 100, 1000]:
    res[num_samples] = {}
    for L in [1e6, 3e6, 6e6, 9e6]:
        ts = msprime.sim_ancestry(num_samples, population_size=1000, sequence_length=L,
                                  recombination_rate=1e-8, record_full_arg=True)
        sts = ts.simplify()
        new_sts = ts.simplify(keep_unary_if_coalescent=True)
        ext_sts, _ = extend_edges(sts)
        res[num_samples][L] = (sts.num_edges, new_sts.num_edges, ext_sts.num_edges)

# %%
fig, axes = plt.subplots(1, 3, figsize=(16, 7))

maxval = 0
for a in res.values():
    for b in a.values():
        maxval = max(maxval, max(b))

for ax, num_samples in zip(axes, res):
    Lvals = list(res[num_samples].keys())
    Lvals.sort()
    sim = [res[num_samples][L][0] for L in Lvals]
    new = [res[num_samples][L][1] for L in Lvals]
    ext = [res[num_samples][L][2] for L in Lvals]
    ax.plot(Lvals, sim, label=f"simplified, ns={num_samples}")
    ax.plot(Lvals, new, label=f"keep unary, ns={num_samples}")
    ax.plot(Lvals, ext, label=f"extended, ns={num_samples}")
    ax.set_xlabel("sequence length")
    ax.set_ylabel("number of edges")
    ax.set_ylim(0, maxval)
    ax.legend();

# %%
maxval
# Out:
# 13969
